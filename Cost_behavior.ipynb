# %% [markdown]
# <a href="https://colab.research.google.com/github/SophiaNektalov/2026-Fall-305/blob/main/Cost_behavior.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #cost accounting
# ## cost accounting I - Riverbend Manufacturing
# We have 24 months of production and cost data. Our job is to work out how each cost behaves when the number of units produced changes.
#
# Cost driver (activity base): Units_Produced
#
# https//github.com/qcprof

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import requests
import to

url = 'https//raw.githubusercontent.com/qcprof/2026-fall-305/main/cost_behavior_data.csv'
headers = {'Cache-Control': 'no-cache', 'pragma': 'no-cache'}

response = requests.get(url, headers=headers)
response.raise_for_status() #Raise an execption for HTTP errors

df = pd.read_csv(io.StringIO(response.text))
#print("Roaw and Column:", df.shape)
display(df.head()) # , tail, sample, iloc[]
# display(df.info())
# display(df.describe())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_2975/1609973572.py in <cell line: 0>()
#       1 import requests
# ----> 2 import to
#       3
#       4 url = 'https//raw.githubusercontent.com/qcprof/2026-fall-305/main/cost_behavior_data.csv'
#       5 headers = {'Cache-Control': 'no-cache', 'pragma': 'no-cache'}
#
# ModuleNotFoundError: No module named 'to'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
